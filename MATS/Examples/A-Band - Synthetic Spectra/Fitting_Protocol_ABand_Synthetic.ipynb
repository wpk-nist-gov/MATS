# %% [markdown]
# # A-Band Fitting Using HAPI MultiSpectrum fitting
# * Loads packages
# * Defines Spectra and Dataset
# * Generates parameter and baseline linelists
# * Fits Data

# %%
## Multi- Spectrum Fitting by Segment

import numpy as np
#import numpy.ma as ma
import pandas as pd
import qgrid
import os
#from lmfit import minimize, Parameters, report_fit, Model, Minimizer
#from lmfit.models import GaussianModel, LinearModel, Model, VoigtModel
import matplotlib.pyplot as plt
from matplotlib import gridspec
#from scipy import interpolate

import sys
# sys.path.append(r'C:\Users\ema3\Documents\MATS\MATS')# set location of HAPI.py module

# %matplotlib inline
from MATS.hapi import *
from MATS.MATS import *

import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
sns.set_context("poster")

# %% [markdown]
# ## Load Spectrum

# %%
from MATS.exampledata import exampledata

# %%
exampledata._cache = {}

# %%
PARAM_LINELIST = exampledata.O2_ABand_Drouin_2017_linelist

# %% [raw]
# #Read in Possible linelists
# hapi = r'C:\Users\ema3\Documents\MATS\MATS\Linelists'
# os.chdir(hapi)
# PARAM_LINELIST = pd.read_csv('O2_ABand_Drouin_2017_linelist.csv')
#
# path = r'C:\Users\ema3\Documents\MATS\MATS\Examples\A-Band - Synthetic Spectra'
# os.chdir(path)

# %%
np.random.seed(0)

# %%
#Generic Fit Parameters
wave_range = 1.5 #range outside of experimental x-range to simulate
IntensityThreshold = 1e-30 #intensities must be above this value to be simulated
Fit_Intensity = 1e-24 #intensities must be above this value for the line to be fit
order_baseline_fit = 1
sample_molefraction = {7 :0.002022}
wave_min = 13155 #cm-1
wave_max = 13157.5 #cm-1
wave_space = 0.005 #cm-1
baseline_terms = [0] #polynomial baseline coefficients where the index is equal to the coefficient order



#Error Sources
##SNR
SNR = 10000

## Wavenumber - adds gaussian noise of given absolute magniture
wave_error = 5e-5

## Temperature
'''
possible keys include 'bias', 'function', and 'params'.  
The bias indicates the absolute bias in Celsius of the temperature reading, which will be added to the input temperature.  
Function can be 'linear' with params 'm' and 'b' or 'sine' with parameters 'amp', 'freq', and 'phase'.  
These define a function that is added to both the bias and set temperature as a function of the wavenumber. 
Note: if 'function' key is not equal to None, then there also needs to be a params key to define the function.
'''
temperature_err =  {'bias': 0.01, 'function': None, 'params': {}}

## Pressure
'''
possible keys include bias, function, and params.  
The bias indicates the percent bias in of the pressure reading, which will be added to the input pressure.  
Function can be 'linear' with params 'm' and 'b' or 'sine' with parameters 'amp', 'freq', and 'phase'.  
These define a function that is added to both the bias and set pressure as a function of the wavenumber. 
Note: if 'function' key is not equal to None, then there also needs to be a params key to define the function.
'''
pressure_err = {'per_bias': 0.01, 'function': None, 'params': {}}
##Mole Fraction
'''
percent error in the mole fraction of each molecule to be simulated in the spectrum
'''
molefraction_err = {7:0.01}

tmp = PARAM_LINELIST
spec_1 =  simulate_spectrum(tmp, wave_min, wave_max, wave_space, wave_error = wave_error, 
                        SNR = SNR, baseline_terms = baseline_terms, temperature = 25, temperature_err = temperature_err, pressure = 20, 
                        pressure_err = pressure_err, 
                        wing_cutoff = 50,  wing_method = 'wing_cutoff', filename = '20_torr', molefraction = sample_molefraction, molefraction_err = molefraction_err,
                        natural_abundance = True, nominal_temperature = 296, IntensityThreshold = 1e-30, num_segments = 1)

spec_2 =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_space, wave_error = wave_error, 
                        SNR = SNR, baseline_terms = baseline_terms, temperature = 25, temperature_err = temperature_err, pressure = 40, 
                        pressure_err = pressure_err, 
                        wing_cutoff = 50,  wing_method = 'wing_cutoff', filename = '40_torr', molefraction = sample_molefraction, molefraction_err = molefraction_err,
                        natural_abundance = True, nominal_temperature = 296, IntensityThreshold = 1e-30, num_segments = 1)
spec_3 =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_space, wave_error = wave_error, 
                        SNR = SNR, baseline_terms = baseline_terms, temperature = 25, temperature_err = temperature_err, pressure = 60, 
                        pressure_err = pressure_err, 
                        wing_cutoff = 50,  wing_method = 'wing_cutoff', filename = '60_torr', molefraction = sample_molefraction, molefraction_err = molefraction_err,
                        natural_abundance = True, nominal_temperature = 296, IntensityThreshold = 1e-30, num_segments = 1)
spec_4 =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_space, wave_error = wave_error, 
                        SNR = SNR, baseline_terms = baseline_terms, temperature = 25, temperature_err = temperature_err, pressure = 80, 
                        pressure_err = pressure_err, 
                        wing_cutoff = 50,  wing_method = 'wing_cutoff', filename = '80_torr', molefraction = sample_molefraction, molefraction_err = molefraction_err,
                        natural_abundance = True, nominal_temperature = 296, IntensityThreshold = 1e-30, num_segments = 1)





spec_1.plot_wave_alpha()

# %% [markdown]
# ## Construct Dataset

# %%
#Add all spectrum to a Dataset object
SPECTRA = Dataset([spec_1, spec_2, spec_3, spec_4], 'Line Intensity', baseline_order = order_baseline_fit)

#Generate Baseline Parameter list based on number of etalons in spectra definitions and baseline order
BASE_LINELIST = SPECTRA.generate_baseline_paramlist()
#BASE_LINELIST = pd.read_csv('Line Intensity_baseline_paramlist.csv')

# %% [markdown]
# ## Generate Fit Parameter Files

# %%
#os.chdir(path)
# Set-up for Fitting
#lineprofile = 'NGP' #VP, SDVP, NGP, SDNGP, HTP


  

FITPARAMS = Generate_FitParam_File(SPECTRA, PARAM_LINELIST, BASE_LINELIST, lineprofile = 'SDVP', linemixing = False, 
                                  fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, sim_window = wave_range,
                                  nu_constrain = False, sw_constrain = False, gamma0_constrain = True, delta0_constrain = True, 
                                   aw_constrain = True, as_constrain = True, 
                                   nuVC_constrain = True, eta_constrain =True, linemixing_constrain = True)

FITPARAMS.generate_fit_param_linelist_from_linelist(vary_nu = {7:{1:True, 2:False, 3:False}}, vary_sw = {7:{1:True, 2:False, 3:False}},
                                                    vary_gamma0 = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma0 = {7:{1:True}}, 
                                                    vary_delta0 = {7:{1: False, 2:False, 3: False}, 1:{1:False}}, vary_n_delta0 = {7:{1:True}}, 
                                                    vary_aw = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma2 = {7:{1:False}}, 
                                                    vary_as = {}, vary_n_delta2 = {7:{1:False}}, 
                                                    vary_nuVC = {7:{1:False}}, vary_n_nuVC = {7:{1:False}},
                                                    vary_eta = {}, vary_linemixing = {7:{1:False}})

FITPARAMS.generate_fit_baseline_linelist(vary_baseline = True, vary_molefraction = {7:False, 1:False}, vary_xshift = False, 
                                      vary_etalon_amp= True, vary_etalon_freq= False, vary_etalon_phase= True, 
                                         vary_pressure = False, vary_temperature = False)
# Out:
#                  Pressure  Pressure_err  Pressure_vary  Segment Number  \
# Spectrum Number
# 1.0              0.026316             0          False             0.0
# 2.0              0.052632             0          False             0.0
# 3.0              0.078947             0          False             0.0
# 4.0              0.105263             0          False             0.0
#
#                  Temperature  Temperature_err  Temperature_vary    baseline_a  \
# Spectrum Number
# 1.0                   298.15                0             False -9.911083e-08
# 2.0                   298.15                0             False -1.925248e-05
# 3.0                   298.15                0             False -4.833483e-05
# 4.0                   298.15                0             False  2.199691e-05
#
#                  baseline_a_err  baseline_a_vary  molefraction_O2  \
# Spectrum Number
# 1.0                           0             True         0.002022
# 2.0                           0             True         0.002022
# 3.0                           0             True         0.002022
# 4.0                           0             True         0.002022
#
#                  molefraction_O2_err  molefraction_O2_vary  x_shift  \
# Spectrum Number
# 1.0                                0                 False      0.0
# 2.0                                0                 False      0.0
# 3.0                                0                 False      0.0
# 4.0                                0                 False      0.0
#
#                  x_shift_err  x_shift_vary
# Spectrum Number
# 1.0                        0         False
# 2.0                        0         False
# 3.0                        0         False
# 4.0                        0         False

# %%
#os.chdir(path)   
fit_data = Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity, 
                baseline_limit = False, baseline_limit_factor = 10, 
                molefraction_limit = False, molefraction_limit_factor = 1.1, 
                etalon_limit = False, etalon_limit_factor = 2, #phase is constrained to +/- 2pi, 
                x_shift_limit = False, x_shift_limit_magnitude = 0.5, 
                nu_limit = False, nu_limit_magnitude = 0.1, 
                sw_limit = False, sw_limit_factor = 2, 
                gamma0_limit = False, gamma0_limit_factor = 3, n_gamma0_limit= False, n_gamma0_limit_factor = 50, 
                delta0_limit = False, delta0_limit_factor = 2, n_delta0_limit = False, n_delta0_limit_factor = 50, 
                SD_gamma_limit = False, SD_gamma_limit_factor = 2, n_gamma2_limit = False, n_gamma2_limit_factor = 50, 
                SD_delta_limit = False, SD_delta_limit_factor = 50, n_delta2_limit = False, n_delta2_limit_factor = 50, 
                nuVC_limit = False, nuVC_limit_factor = 2, n_nuVC_limit = False, n_nuVC_limit_factor = 50, 
                eta_limit = False, eta_limit_factor = 50, linemixing_limit = False, linemixing_limit_factor = 50)
params = fit_data.generate_params()




#print (params)

#add_expr_params(self, params, param_name, expr)

result = fit_data.fit_data(params, wing_cutoff = 25, wing_wavenumbers = 1)

# %%
def params_to_frame(params):
    df = pd.DataFrame([
        dict(name=v.name, value=v.value, init_value=v.init_value, min=v.min, max=v.max, vary=v.vary, stderr=v.stderr)
        for k, v in params.items()
    ]).set_index('name')
    return df

# %% [raw]
# out_df = params_to_frame(result.params)

# %%
out_df2 = params_to_frame(result.params)

# %%
pd.testing.assert_frame_equal(out_df, out_df2)

# %%
print (result.params.pretty_print())

fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
SPECTRA.plot_model_residuals()
# Out:
# Name                     Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_0           0.02632     -inf      inf        0    False     None     None
# Pressure_2_0           0.05263     -inf      inf        0    False     None     None
# Pressure_3_0           0.07895     -inf      inf        0    False     None     None
# Pressure_4_0            0.1053     -inf      inf        0    False     None     None
# SD_delta_air_line_12         0     -inf      inf        0    False     None     None
# SD_delta_air_line_15         0     -inf      inf        0    False     None     None
# SD_delta_air_line_27         0     -inf      inf        0    False     None     None
# SD_delta_air_line_28         0     -inf      inf        0    False     None     None
# SD_delta_air_line_3          0     -inf      inf        0    False     None     None
# SD_gamma_air_line_12   0.08373        0      inf 0.0008903     True     None     None
# SD_gamma_air_line_15   0.09303        0      inf  0.00127     True     None     None
# SD_gamma_air_line_27      0.09        0      inf        0    False     None     None
# SD_gamma_air_line_28       0.1        0      inf        0    False     None     None
# SD_gamma_air_line_3        0.1        0      inf        0    False     None     None
# Temperature_1_0          298.1     -inf      inf        0    False     None     None
# Temperature_2_0          298.1     -inf      inf        0    False     None     None
# Temperature_3_0          298.1     -inf      inf        0    False     None     None
# Temperature_4_0          298.1     -inf      inf        0    False     None     None
# baseline_a_1_0        3.963e-06     -inf      inf 6.588e-06     True     None     None
# baseline_a_2_0        1.771e-05     -inf      inf 6.618e-06     True     None     None
# baseline_a_3_0        3.42e-05     -inf      inf 6.703e-06     True     None     None
# baseline_a_4_0        5.965e-05     -inf      inf 6.895e-06     True     None     None
# delta0_air_line_12    -0.007967     -inf      inf        0    False     None     None
# delta0_air_line_15    -0.008547     -inf      inf        0    False     None     None
# delta0_air_line_27    -0.008741     -inf      inf        0    False     None     None
# delta0_air_line_28    -0.008568     -inf      inf        0    False     None     None
# delta0_air_line_3     -0.007977     -inf      inf        0    False     None     None
# eta_air_line_12              0     -inf      inf        0    False     None     None
# eta_air_line_15              0     -inf      inf        0    False     None     None
# eta_air_line_27              0     -inf      inf        0    False     None     None
# eta_air_line_28              0     -inf      inf        0    False     None     None
# eta_air_line_3               0     -inf      inf        0    False     None     None
# gamma0_air_line_12     0.03996     -inf      inf 4.512e-05     True     None     None
# gamma0_air_line_15      0.0398     -inf      inf 6.927e-05     True     None     None
# gamma0_air_line_27        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_28        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_3         0.04     -inf      inf        0    False     None     None
# molefraction_O2_1_0   0.002022     -inf      inf        0    False     None     None
# molefraction_O2_2_0   0.002022     -inf      inf        0    False     None     None
# molefraction_O2_3_0   0.002022     -inf      inf        0    False     None     None
# molefraction_O2_4_0   0.002022     -inf      inf        0    False     None     None
# nuVC_air_line_12             0     -inf      inf        0    False     None     None
# nuVC_air_line_15             0     -inf      inf        0    False     None     None
# nuVC_air_line_27             0     -inf      inf        0    False     None     None
# nuVC_air_line_28             0     -inf      inf        0    False     None     None
# nuVC_air_line_3              0     -inf      inf        0    False     None     None
# nu_1_line_12          1.316e+04     -inf      inf 6.366e-06     True     None     None
# nu_1_line_15          1.316e+04     -inf      inf 9.726e-06     True     None     None
# nu_1_line_27          1.316e+04     -inf      inf        0    False     None     None
# nu_1_line_28          1.316e+04     -inf      inf        0    False     None     None
# nu_1_line_3           1.315e+04     -inf      inf        0    False     None     None
# nu_2_line_12          1.316e+04     -inf      inf 3.464e-06     True     None     None
# nu_2_line_15          1.316e+04     -inf      inf 5.286e-06     True     None     None
# nu_2_line_27          1.316e+04     -inf      inf        0    False     None     None
# nu_2_line_28          1.316e+04     -inf      inf        0    False     None     None
# nu_2_line_3           1.315e+04     -inf      inf        0    False     None     None
# nu_3_line_12          1.316e+04     -inf      inf 2.514e-06     True     None     None
# nu_3_line_15          1.316e+04     -inf      inf 3.826e-06     True     None     None
# nu_3_line_27          1.316e+04     -inf      inf        0    False     None     None
# nu_3_line_28          1.316e+04     -inf      inf        0    False     None     None
# nu_3_line_3           1.315e+04     -inf      inf        0    False     None     None
# nu_4_line_12          1.316e+04     -inf      inf 2.042e-06     True     None     None
# nu_4_line_15          1.316e+04     -inf      inf 3.112e-06     True     None     None
# nu_4_line_27          1.316e+04     -inf      inf        0    False     None     None
# nu_4_line_28          1.316e+04     -inf      inf        0    False     None     None
# nu_4_line_3           1.315e+04     -inf      inf        0    False     None     None
# sw_1_line_12             4.792     -inf      inf 0.001716     True     None     None
# sw_1_line_15             3.126     -inf      inf 0.001713     True     None     None
# sw_1_line_27             2.083     -inf      inf        0    False     None     None
# sw_1_line_28             3.399     -inf      inf        0    False     None     None
# sw_1_line_3              4.369     -inf      inf        0    False     None     None
# sw_2_line_12             4.801     -inf      inf 0.0009606     True     None     None
# sw_2_line_15             3.126     -inf      inf 0.0009571     True     None     None
# sw_2_line_27             2.083     -inf      inf        0    False     None     None
# sw_2_line_28             3.399     -inf      inf        0    False     None     None
# sw_2_line_3              4.369     -inf      inf        0    False     None     None
# sw_3_line_12             4.794     -inf      inf 0.0008058     True     None     None
# sw_3_line_15             3.121     -inf      inf 0.000803     True     None     None
# sw_3_line_27             2.083     -inf      inf        0    False     None     None
# sw_3_line_28             3.399     -inf      inf        0    False     None     None
# sw_3_line_3              4.369     -inf      inf        0    False     None     None
# sw_4_line_12             4.793     -inf      inf 0.0008232     True     None     None
# sw_4_line_15             3.126     -inf      inf 0.0008204     True     None     None
# sw_4_line_27             2.083     -inf      inf        0    False     None     None
# sw_4_line_28             3.399     -inf      inf        0    False     None     None
# sw_4_line_3              4.369     -inf      inf        0    False     None     None
# x_shift_1_0                  0     -inf      inf        0    False     None     None
# x_shift_2_0                  0     -inf      inf        0    False     None     None
# x_shift_3_0                  0     -inf      inf        0    False     None     None
# x_shift_4_0                  0     -inf      inf        0    False     None     None
# y_air_296_line_12            0     -inf      inf        0    False     None     None
# y_air_296_line_15            0     -inf      inf        0    False     None     None
# y_air_296_line_27            0     -inf      inf        0    False     None     None
# y_air_296_line_28            0     -inf      inf        0    False     None     None
# y_air_296_line_3             0     -inf      inf        0    False     None     None
# None

# %% [markdown]
# # limited number of spectra

# %%
#Add all spectrum to a Dataset object
X = [spec_1, spec_2]
SPECTRA2 = Dataset(X, 'Line Intensity', baseline_order = order_baseline_fit)

# %%
#Generate Baseline Parameter list based on number of etalons in spectra definitions and baseline order
BASE_LINELIST2 = SPECTRA2.generate_baseline_paramlist()
##BASE_LINELIST = pd.read_csv('Line Intensity_baseline_paramlist.csv')

# %%
#os.chdir(path)
# Set-up for Fitting
#lineprofile = 'NGP' #VP, SDVP, NGP, SDNGP, HTP


  

FITPARAMS2 = Generate_FitParam_File(SPECTRA2, PARAM_LINELIST, 
                                    BASE_LINELIST2, lineprofile = 'SDVP', 
                                    linemixing = False, 
                                  fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, sim_window = wave_range,
                                  nu_constrain = False, sw_constrain = False, gamma0_constrain = True, delta0_constrain = True, 
                                   aw_constrain = True, as_constrain = True, 
                                   nuVC_constrain = True, eta_constrain =True, linemixing_constrain = True)

FITPARAMS2.generate_fit_param_linelist_from_linelist(vary_nu = {7:{1:True, 2:False, 3:False}}, vary_sw = {7:{1:True, 2:False, 3:False}},
                                                    vary_gamma0 = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma0 = {7:{1:True}}, 
                                                    vary_delta0 = {7:{1: False, 2:False, 3: False}, 1:{1:False}}, vary_n_delta0 = {7:{1:True}}, 
                                                    vary_aw = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma2 = {7:{1:False}}, 
                                                    vary_as = {}, vary_n_delta2 = {7:{1:False}}, 
                                                    vary_nuVC = {7:{1:False}}, vary_n_nuVC = {7:{1:False}},
                                                    vary_eta = {}, vary_linemixing = {7:{1:False}})

FITPARAMS2.generate_fit_baseline_linelist(vary_baseline = True, vary_molefraction = {7:False, 1:False}, vary_xshift = False, 
                                      vary_etalon_amp= True, vary_etalon_freq= False, vary_etalon_phase= True, 
                                         vary_pressure = False, vary_temperature = False)
# Out:
#                  Pressure  Pressure_err  Pressure_vary  Segment Number  \
# Spectrum Number
# 1.0              0.026316             0          False             0.0
# 2.0              0.052632             0          False             0.0
#
#                  Temperature  Temperature_err  Temperature_vary  baseline_a  \
# Spectrum Number
# 1.0                   298.15                0             False    0.000031
# 2.0                   298.15                0             False    0.000020
#
#                  baseline_a_err  baseline_a_vary  molefraction_O2  \
# Spectrum Number
# 1.0                           0             True         0.002022
# 2.0                           0             True         0.002022
#
#                  molefraction_O2_err  molefraction_O2_vary  x_shift  \
# Spectrum Number
# 1.0                                0                 False      0.0
# 2.0                                0                 False      0.0
#
#                  x_shift_err  x_shift_vary
# Spectrum Number
# 1.0                        0         False
# 2.0                        0         False

# %%
#os.chdir(path)   
fit_data2 = Fit_DataSet(SPECTRA2,'Baseline_LineList', 'Parameter_LineList',
                        minimum_parameter_fit_intensity = Fit_Intensity, 
                baseline_limit = False, baseline_limit_factor = 10, 
                molefraction_limit = False, molefraction_limit_factor = 1.1, 
                etalon_limit = False, etalon_limit_factor = 2, #phase is constrained to +/- 2pi, 
                x_shift_limit = False, x_shift_limit_magnitude = 0.5, 
                nu_limit = False, nu_limit_magnitude = 0.1, 
                sw_limit = False, sw_limit_factor = 2, 
                gamma0_limit = False, gamma0_limit_factor = 3, n_gamma0_limit= False, n_gamma0_limit_factor = 50, 
                delta0_limit = False, delta0_limit_factor = 2, n_delta0_limit = False, n_delta0_limit_factor = 50, 
                SD_gamma_limit = False, SD_gamma_limit_factor = 2, n_gamma2_limit = False, n_gamma2_limit_factor = 50, 
                SD_delta_limit = False, SD_delta_limit_factor = 50, n_delta2_limit = False, n_delta2_limit_factor = 50, 
                nuVC_limit = False, nuVC_limit_factor = 2, n_nuVC_limit = False, n_nuVC_limit_factor = 50, 
                eta_limit = False, eta_limit_factor = 50, linemixing_limit = False, linemixing_limit_factor = 50)
params2 = fit_data2.generate_params()




#print (params)

#add_expr_params(self, params, param_name, expr)

result2 = fit_data2.fit_data(params2, wing_cutoff = 25, wing_wavenumbers = 1)
print (result2.params.pretty_print())

fit_data2.residual_analysis(result2, indv_resid_plot=True)
fit_data2.update_params(result2)
SPECTRA2.generate_summary_file(save_file = True)
SPECTRA2.plot_model_residuals()
# Out:
# Name                     Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_0           0.02632     -inf      inf        0    False     None     None
# Pressure_2_0           0.05263     -inf      inf        0    False     None     None
# SD_delta_air_line_12         0     -inf      inf        0    False     None     None
# SD_delta_air_line_15         0     -inf      inf        0    False     None     None
# SD_delta_air_line_27         0     -inf      inf        0    False     None     None
# SD_delta_air_line_28         0     -inf      inf        0    False     None     None
# SD_delta_air_line_3          0     -inf      inf        0    False     None     None
# SD_gamma_air_line_12   0.08463        0      inf 0.002296     True     None     None
# SD_gamma_air_line_15    0.1101        0      inf 0.003497     True     None     None
# SD_gamma_air_line_27      0.09        0      inf        0    False     None     None
# SD_gamma_air_line_28       0.1        0      inf        0    False     None     None
# SD_gamma_air_line_3        0.1        0      inf        0    False     None     None
# Temperature_1_0          298.1     -inf      inf        0    False     None     None
# Temperature_2_0          298.1     -inf      inf        0    False     None     None
# baseline_a_1_0        3.407e-06     -inf      inf 4.693e-06     True     None     None
# baseline_a_2_0        1.495e-05     -inf      inf 4.921e-06     True     None     None
# delta0_air_line_12    -0.007967     -inf      inf        0    False     None     None
# delta0_air_line_15    -0.008547     -inf      inf        0    False     None     None
# delta0_air_line_27    -0.008741     -inf      inf        0    False     None     None
# delta0_air_line_28    -0.008568     -inf      inf        0    False     None     None
# delta0_air_line_3     -0.007977     -inf      inf        0    False     None     None
# eta_air_line_12              0     -inf      inf        0    False     None     None
# eta_air_line_15              0     -inf      inf        0    False     None     None
# eta_air_line_27              0     -inf      inf        0    False     None     None
# eta_air_line_28              0     -inf      inf        0    False     None     None
# eta_air_line_3               0     -inf      inf        0    False     None     None
# gamma0_air_line_12     0.03997     -inf      inf 0.000129     True     None     None
# gamma0_air_line_15        0.04     -inf      inf 0.0001977     True     None     None
# gamma0_air_line_27        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_28        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_3         0.04     -inf      inf        0    False     None     None
# molefraction_O2_1_0   0.002022     -inf      inf        0    False     None     None
# molefraction_O2_2_0   0.002022     -inf      inf        0    False     None     None
# nuVC_air_line_12             0     -inf      inf        0    False     None     None
# nuVC_air_line_15             0     -inf      inf        0    False     None     None
# nuVC_air_line_27             0     -inf      inf        0    False     None     None
# nuVC_air_line_28             0     -inf      inf        0    False     None     None
# nuVC_air_line_3              0     -inf      inf        0    False     None     None
# nu_1_line_12          1.316e+04     -inf      inf 4.51e-06     True     None     None
# nu_1_line_15          1.316e+04     -inf      inf 6.893e-06     True     None     None
# nu_1_line_27          1.316e+04     -inf      inf        0    False     None     None
# nu_1_line_28          1.316e+04     -inf      inf        0    False     None     None
# nu_1_line_3           1.315e+04     -inf      inf        0    False     None     None
# nu_2_line_12          1.316e+04     -inf      inf 2.459e-06     True     None     None
# nu_2_line_15          1.316e+04     -inf      inf 3.749e-06     True     None     None
# nu_2_line_27          1.316e+04     -inf      inf        0    False     None     None
# nu_2_line_28          1.316e+04     -inf      inf        0    False     None     None
# nu_2_line_3           1.315e+04     -inf      inf        0    False     None     None
# sw_1_line_12             4.799     -inf      inf 0.001326     True     None     None
# sw_1_line_15             3.122     -inf      inf 0.001321     True     None     None
# sw_1_line_27             2.083     -inf      inf        0    False     None     None
# sw_1_line_28             3.399     -inf      inf        0    False     None     None
# sw_1_line_3              4.369     -inf      inf        0    False     None     None
# sw_2_line_12             4.795     -inf      inf 0.001217     True     None     None
# sw_2_line_15             3.122     -inf      inf 0.001214     True     None     None
# sw_2_line_27             2.083     -inf      inf        0    False     None     None
# sw_2_line_28             3.399     -inf      inf        0    False     None     None
# sw_2_line_3              4.369     -inf      inf        0    False     None     None
# x_shift_1_0                  0     -inf      inf        0    False     None     None
# x_shift_2_0                  0     -inf      inf        0    False     None     None
# y_air_296_line_12            0     -inf      inf        0    False     None     None
# y_air_296_line_15            0     -inf      inf        0    False     None     None
# y_air_296_line_27            0     -inf      inf        0    False     None     None
# y_air_296_line_28            0     -inf      inf        0    False     None     None
# y_air_296_line_3             0     -inf      inf        0    False     None     None
# None

# %%
def params_to_frame(params):
    df = pd.DataFrame([
        dict(name=v.name, value=v.value, init_value=v.init_value, min=v.min, max=v.max, vary=v.vary, stderr=v.stderr)
        for k, v in params.items()
    ]).set_index('name')
    return df

# %%
a = params_to_frame(params)
b = params_to_frame(params2)

# %%
(a.value - b.value).dropna()
# Out:
# name
# Pressure_1_0            0.0
# Pressure_2_0            0.0
# SD_delta_air_line_12    0.0
# SD_delta_air_line_15    0.0
# SD_delta_air_line_27    0.0
#                        ...
# y_air_296_line_12       0.0
# y_air_296_line_15       0.0
# y_air_296_line_27       0.0
# y_air_296_line_28       0.0
# y_air_296_line_3        0.0
# Name: value, Length: 65, dtype: float64

# %%
a = params_to_frame(result.params)
b = params_to_frame(result2.params)

# %%
(a - b)[['value','init_value','stderr']].dropna().query('value !=0')
# Out:
#                              value  init_value        stderr
# name
# SD_gamma_air_line_12 -1.147968e-02   -0.006708 -1.479829e-03
# SD_gamma_air_line_15 -1.598388e-02   -0.005786 -2.273793e-03
# baseline_a_1_0       -4.272315e-07   -0.000028  1.413457e-06
# baseline_a_2_0       -1.429902e-06   -0.000007  1.212497e-06
# gamma0_air_line_12   -2.010906e-04   -0.000233 -8.718576e-05
# gamma0_air_line_15   -1.288807e-04   -0.000125 -1.336175e-04
# nu_1_line_12         -1.049448e-07    0.000003  1.377286e-06
# nu_1_line_15         -6.357186e-08    0.000014  2.108078e-06
# nu_2_line_12         -1.806184e-07   -0.000011  7.537161e-07
# nu_2_line_15         -1.264871e-07   -0.000008  1.147344e-06
# sw_1_line_12          1.180863e-04    0.000482  2.661146e-04
# sw_1_line_15          6.297521e-04   -0.000135  2.651089e-04
# sw_2_line_12          1.270606e-04   -0.003706 -3.281044e-04
# sw_2_line_15          1.110153e-03   -0.000102 -3.274819e-04

# %%
pd.merge(*[x[['value','stderr']] for x in [a,b]], left_index=True, right_index=True)
# Out:
#                          value_x  stderr_x     value_y  stderr_y
# name
# Pressure_1_0            0.026316  0.000000    0.026316  0.000000
# Temperature_1_0       298.150000  0.000000  298.150000  0.000000
# baseline_a_1_0          0.000003  0.000006    0.000003  0.000005
# molefraction_O2_1_0     0.002022  0.000000    0.002022  0.000000
# x_shift_1_0             0.000000  0.000000    0.000000  0.000000
# ...                          ...       ...         ...       ...
# nuVC_air_line_28        0.000000  0.000000    0.000000  0.000000
# SD_gamma_air_line_28    0.100000  0.000000    0.100000  0.000000
# SD_delta_air_line_28    0.000000  0.000000    0.000000  0.000000
# eta_air_line_28         0.000000  0.000000    0.000000  0.000000
# y_air_296_line_28       0.000000  0.000000    0.000000  0.000000
#
# [65 rows x 4 columns]

# %%
a.join(b, lsuffix='', rsuffix='_2')
# Out:
#                            value  init_value  min  max   vary    stderr  \
# name
# Pressure_1_0            0.026316    0.026316 -inf  inf  False  0.000000
# Temperature_1_0       298.150000  298.150000 -inf  inf  False  0.000000
# baseline_a_1_0          0.000003    0.000003 -inf  inf   True  0.000006
# molefraction_O2_1_0     0.002022    0.002022 -inf  inf  False  0.000000
# x_shift_1_0             0.000000    0.000000 -inf  inf  False  0.000000
# ...                          ...         ...  ...  ...    ...       ...
# nuVC_air_line_28        0.000000    0.000000 -inf  inf  False  0.000000
# SD_gamma_air_line_28    0.100000    0.100000  0.0  inf  False  0.000000
# SD_delta_air_line_28    0.000000    0.000000 -inf  inf  False  0.000000
# eta_air_line_28         0.000000    0.000000 -inf  inf  False  0.000000
# y_air_296_line_28       0.000000    0.000000 -inf  inf  False  0.000000
#
#                          value_2  init_value_2  min_2  max_2 vary_2  stderr_2
# name
# Pressure_1_0            0.026316      0.026316   -inf    inf  False  0.000000
# Temperature_1_0       298.150000    298.150000   -inf    inf  False  0.000000
# baseline_a_1_0          0.000003      0.000031   -inf    inf   True  0.000005
# molefraction_O2_1_0     0.002022      0.002022   -inf    inf  False  0.000000
# x_shift_1_0             0.000000      0.000000   -inf    inf  False  0.000000
# ...                          ...           ...    ...    ...    ...       ...
# nuVC_air_line_28        0.000000      0.000000   -inf    inf  False  0.000000
# SD_gamma_air_line_28    0.100000      0.100000    0.0    inf  False  0.000000
# SD_delta_air_line_28    0.000000      0.000000   -inf    inf  False  0.000000
# eta_air_line_28         0.000000      0.000000   -inf    inf  False  0.000000
# y_air_296_line_28       0.000000      0.000000   -inf    inf  False  0.000000
#
# [95 rows x 12 columns]

# %%
pd.merge((a, b), left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-213-8e0a01fddcb0> in <module>
# ----> 1 pd.merge((a, b), left_index=True, right_index=True)
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
for k, v in params.items():
    break

# %%
for k, r in result.params.items():

    break

# %%
r = result.params['baseline_a_1_0']

# %%
v.stderr

# %%
params
# Out:
# Parameters([('Pressure_1_0',
#              <Parameter 'Pressure_1_0', value=0.0263157894736842 (fixed), bounds=[-inf:inf]>),
#             ('Temperature_1_0',
#              <Parameter 'Temperature_1_0', value=298.15 (fixed), bounds=[-inf:inf]>),
#             ('baseline_a_1_0',
#              <Parameter 'baseline_a_1_0', value=2.9719215990152512e-06, bounds=[-inf:inf]>),
#             ('molefraction_O2_1_0',
#              <Parameter 'molefraction_O2_1_0', value=0.002022 (fixed), bounds=[-inf:inf]>),
#             ('x_shift_1_0',
#              <Parameter 'x_shift_1_0', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('Pressure_2_0',
#              <Parameter 'Pressure_2_0', value=0.0526315789473684 (fixed), bounds=[-inf:inf]>),
#             ('Temperature_2_0',
#              <Parameter 'Temperature_2_0', value=298.15 (fixed), bounds=[-inf:inf]>),
#             ('baseline_a_2_0',
#              <Parameter 'baseline_a_2_0', value=1.3544228176162892e-05, bounds=[-inf:inf]>),
#             ('molefraction_O2_2_0',
#              <Parameter 'molefraction_O2_2_0', value=0.002022 (fixed), bounds=[-inf:inf]>),
#             ('x_shift_2_0',
#              <Parameter 'x_shift_2_0', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('Pressure_3_0',
#              <Parameter 'Pressure_3_0', value=0.0789473684210526 (fixed), bounds=[-inf:inf]>),
#             ('Temperature_3_0',
#              <Parameter 'Temperature_3_0', value=298.15 (fixed), bounds=[-inf:inf]>),
#             ('baseline_a_3_0',
#              <Parameter 'baseline_a_3_0', value=3.915319229352542e-05, bounds=[-inf:inf]>),
#             ('molefraction_O2_3_0',
#              <Parameter 'molefraction_O2_3_0', value=0.002022 (fixed), bounds=[-inf:inf]>),
#             ('x_shift_3_0',
#              <Parameter 'x_shift_3_0', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('Pressure_4_0',
#              <Parameter 'Pressure_4_0', value=0.1052631578947368 (fixed), bounds=[-inf:inf]>),
#             ('Temperature_4_0',
#              <Parameter 'Temperature_4_0', value=298.15 (fixed), bounds=[-inf:inf]>),
#             ('baseline_a_4_0',
#              <Parameter 'baseline_a_4_0', value=5.7724449701968336e-05, bounds=[-inf:inf]>),
#             ('molefraction_O2_4_0',
#              <Parameter 'molefraction_O2_4_0', value=0.002022 (fixed), bounds=[-inf:inf]>),
#             ('x_shift_4_0',
#              <Parameter 'x_shift_4_0', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_3',
#              <Parameter 'nu_1_line_3', value=13154.18 (fixed), bounds=[-inf:inf]>),
#             ('nu_2_line_3',
#              <Parameter 'nu_2_line_3', value=13154.18 (fixed), bounds=[-inf:inf]>),
#             ('nu_3_line_3',
#              <Parameter 'nu_3_line_3', value=13154.18 (fixed), bounds=[-inf:inf]>),
#             ('nu_4_line_3',
#              <Parameter 'nu_4_line_3', value=13154.18 (fixed), bounds=[-inf:inf]>),
#             ('sw_1_line_3',
#              <Parameter 'sw_1_line_3', value=4.369 (fixed), bounds=[-inf:inf]>),
#             ('sw_2_line_3',
#              <Parameter 'sw_2_line_3', value=4.369 (fixed), bounds=[-inf:inf]>),
#             ('sw_3_line_3',
#              <Parameter 'sw_3_line_3', value=4.369 (fixed), bounds=[-inf:inf]>),
#             ('sw_4_line_3',
#              <Parameter 'sw_4_line_3', value=4.369 (fixed), bounds=[-inf:inf]>),
#             ('gamma0_air_line_3',
#              <Parameter 'gamma0_air_line_3', value=0.04 (fixed), bounds=[-inf:inf]>),
#             ('delta0_air_line_3',
#              <Parameter 'delta0_air_line_3', value=-0.007977 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_3',
#              <Parameter 'nuVC_air_line_3', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_3',
#              <Parameter 'SD_gamma_air_line_3', value=0.1 (fixed), bounds=[0:inf]>),
#             ('SD_delta_air_line_3',
#              <Parameter 'SD_delta_air_line_3', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_3',
#              <Parameter 'eta_air_line_3', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_3',
#              <Parameter 'y_air_296_line_3', value=0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_12',
#              <Parameter 'nu_1_line_12', value=13156.280003354896, bounds=[-inf:inf]>),
#             ('nu_2_line_12',
#              <Parameter 'nu_2_line_12', value=13156.27998913494, bounds=[-inf:inf]>),
#             ('nu_3_line_12',
#              <Parameter 'nu_3_line_12', value=13156.279986337866, bounds=[-inf:inf]>),
#             ('nu_4_line_12',
#              <Parameter 'nu_4_line_12', value=13156.280007140676, bounds=[-inf:inf]>),
#             ('sw_1_line_12',
#              <Parameter 'sw_1_line_12', value=4.799481692034503, bounds=[-inf:inf]>),
#             ('sw_2_line_12',
#              <Parameter 'sw_2_line_12', value=4.795293526168948, bounds=[-inf:inf]>),
#             ('sw_3_line_12',
#              <Parameter 'sw_3_line_12', value=4.798792824615132, bounds=[-inf:inf]>),
#             ('sw_4_line_12',
#              <Parameter 'sw_4_line_12', value=4.797280484117155, bounds=[-inf:inf]>),
#             ('gamma0_air_line_12',
#              <Parameter 'gamma0_air_line_12', value=0.0397666170607502, bounds=[-inf:inf]>),
#             ('delta0_air_line_12',
#              <Parameter 'delta0_air_line_12', value=-0.007967 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_12',
#              <Parameter 'nuVC_air_line_12', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_12',
#              <Parameter 'SD_gamma_air_line_12', value=0.0732919633111148, bounds=[0:inf]>),
#             ('SD_delta_air_line_12',
#              <Parameter 'SD_delta_air_line_12', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_12',
#              <Parameter 'eta_air_line_12', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_12',
#              <Parameter 'y_air_296_line_12', value=0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_15',
#              <Parameter 'nu_1_line_15', value=13156.62001363543, bounds=[-inf:inf]>),
#             ('nu_2_line_15',
#              <Parameter 'nu_2_line_15', value=13156.619992308411, bounds=[-inf:inf]>),
#             ('nu_3_line_15',
#              <Parameter 'nu_3_line_15', value=13156.62000978661, bounds=[-inf:inf]>),
#             ('nu_4_line_15',
#              <Parameter 'nu_4_line_15', value=13156.620012222496, bounds=[-inf:inf]>),
#             ('sw_1_line_15',
#              <Parameter 'sw_1_line_15', value=3.1228647528782165, bounds=[-inf:inf]>),
#             ('sw_2_line_15',
#              <Parameter 'sw_2_line_15', value=3.1228984228451604, bounds=[-inf:inf]>),
#             ('sw_3_line_15',
#              <Parameter 'sw_3_line_15', value=3.1258638166203974, bounds=[-inf:inf]>),
#             ('sw_4_line_15',
#              <Parameter 'sw_4_line_15', value=3.125757815541521, bounds=[-inf:inf]>),
#             ('gamma0_air_line_15',
#              <Parameter 'gamma0_air_line_15', value=0.0398751413263322, bounds=[-inf:inf]>),
#             ('delta0_air_line_15',
#              <Parameter 'delta0_air_line_15', value=-0.0085469999999999 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_15',
#              <Parameter 'nuVC_air_line_15', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_15',
#              <Parameter 'SD_gamma_air_line_15', value=0.0942144322289282, bounds=[0:inf]>),
#             ('SD_delta_air_line_15',
#              <Parameter 'SD_delta_air_line_15', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_15',
#              <Parameter 'eta_air_line_15', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_15',
#              <Parameter 'y_air_296_line_15', value=0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_27',
#              <Parameter 'nu_1_line_27', value=13158.68 (fixed), bounds=[-inf:inf]>),
#             ('nu_2_line_27',
#              <Parameter 'nu_2_line_27', value=13158.68 (fixed), bounds=[-inf:inf]>),
#             ('nu_3_line_27',
#              <Parameter 'nu_3_line_27', value=13158.68 (fixed), bounds=[-inf:inf]>),
#             ('nu_4_line_27',
#              <Parameter 'nu_4_line_27', value=13158.68 (fixed), bounds=[-inf:inf]>),
#             ('sw_1_line_27',
#              <Parameter 'sw_1_line_27', value=2.083 (fixed), bounds=[-inf:inf]>),
#             ('sw_2_line_27',
#              <Parameter 'sw_2_line_27', value=2.083 (fixed), bounds=[-inf:inf]>),
#             ('sw_3_line_27',
#              <Parameter 'sw_3_line_27', value=2.083 (fixed), bounds=[-inf:inf]>),
#             ('sw_4_line_27',
#              <Parameter 'sw_4_line_27', value=2.083 (fixed), bounds=[-inf:inf]>),
#             ('gamma0_air_line_27',
#              <Parameter 'gamma0_air_line_27', value=0.04 (fixed), bounds=[-inf:inf]>),
#             ('delta0_air_line_27',
#              <Parameter 'delta0_air_line_27', value=-0.0087411 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_27',
#              <Parameter 'nuVC_air_line_27', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_27',
#              <Parameter 'SD_gamma_air_line_27', value=0.09 (fixed), bounds=[0:inf]>),
#             ('SD_delta_air_line_27',
#              <Parameter 'SD_delta_air_line_27', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_27',
#              <Parameter 'eta_air_line_27', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_27',
#              <Parameter 'y_air_296_line_27', value=0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_28',
#              <Parameter 'nu_1_line_28', value=13158.74 (fixed), bounds=[-inf:inf]>),
#             ('nu_2_line_28',
#              <Parameter 'nu_2_line_28', value=13158.74 (fixed), bounds=[-inf:inf]>),
#             ('nu_3_line_28',
#              <Parameter 'nu_3_line_28', value=13158.74 (fixed), bounds=[-inf:inf]>),
#             ('nu_4_line_28',
#              <Parameter 'nu_4_line_28', value=13158.74 (fixed), bounds=[-inf:inf]>),
#             ('sw_1_line_28',
#              <Parameter 'sw_1_line_28', value=3.399 (fixed), bounds=[-inf:inf]>),
#             ('sw_2_line_28',
#              <Parameter 'sw_2_line_28', value=3.399 (fixed), bounds=[-inf:inf]>),
#             ('sw_3_line_28',
#              <Parameter 'sw_3_line_28', value=3.399 (fixed), bounds=[-inf:inf]>),
#             ('sw_4_line_28',
#              <Parameter 'sw_4_line_28', value=3.399 (fixed), bounds=[-inf:inf]>),
#             ('gamma0_air_line_28',
#              <Parameter 'gamma0_air_line_28', value=0.04 (fixed), bounds=[-inf:inf]>),
#             ('delta0_air_line_28',
#              <Parameter 'delta0_air_line_28', value=-0.008568 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_28',
#              <Parameter 'nuVC_air_line_28', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_28',
#              <Parameter 'SD_gamma_air_line_28', value=0.1 (fixed), bounds=[0:inf]>),
#             ('SD_delta_air_line_28',
#              <Parameter 'SD_delta_air_line_28', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_28',
#              <Parameter 'eta_air_line_28', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_28',
#              <Parameter 'y_air_296_line_28', value=0 (fixed), bounds=[-inf:inf]>)])

# %%
result.params
# Out:
# /Users/wpk/miniforge3/envs/MATS-env/lib/python3.8/site-packages/lmfit/printfuncs.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   spercent = '({:.2%})'.format(abs(par.stderr/par.value))
# /Users/wpk/miniforge3/envs/MATS-env/lib/python3.8/site-packages/lmfit/printfuncs.py:321: RuntimeWarning: invalid value encountered in long_scalars
#   spercent = '({:.2%})'.format(abs(par.stderr/par.value))
# Parameters([('Pressure_1_0',
#              <Parameter 'Pressure_1_0', value=0.0263157894736842 (fixed), bounds=[-inf:inf]>),
#             ('Temperature_1_0',
#              <Parameter 'Temperature_1_0', value=298.15 (fixed), bounds=[-inf:inf]>),
#             ('baseline_a_1_0',
#              <Parameter 'baseline_a_1_0', value=2.980119273127728e-06 +/- 6.11e-06, bounds=[-inf:inf]>),
#             ('molefraction_O2_1_0',
#              <Parameter 'molefraction_O2_1_0', value=0.002022 (fixed), bounds=[-inf:inf]>),
#             ('x_shift_1_0',
#              <Parameter 'x_shift_1_0', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('Pressure_2_0',
#              <Parameter 'Pressure_2_0', value=0.0526315789473684 (fixed), bounds=[-inf:inf]>),
#             ('Temperature_2_0',
#              <Parameter 'Temperature_2_0', value=298.15 (fixed), bounds=[-inf:inf]>),
#             ('baseline_a_2_0',
#              <Parameter 'baseline_a_2_0', value=1.3515717724623401e-05 +/- 6.13e-06, bounds=[-inf:inf]>),
#             ('molefraction_O2_2_0',
#              <Parameter 'molefraction_O2_2_0', value=0.002022 (fixed), bounds=[-inf:inf]>),
#             ('x_shift_2_0',
#              <Parameter 'x_shift_2_0', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('Pressure_3_0',
#              <Parameter 'Pressure_3_0', value=0.0789473684210526 (fixed), bounds=[-inf:inf]>),
#             ('Temperature_3_0',
#              <Parameter 'Temperature_3_0', value=298.15 (fixed), bounds=[-inf:inf]>),
#             ('baseline_a_3_0',
#              <Parameter 'baseline_a_3_0', value=3.9124481032127156e-05 +/- 6.21e-06, bounds=[-inf:inf]>),
#             ('molefraction_O2_3_0',
#              <Parameter 'molefraction_O2_3_0', value=0.002022 (fixed), bounds=[-inf:inf]>),
#             ('x_shift_3_0',
#              <Parameter 'x_shift_3_0', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('Pressure_4_0',
#              <Parameter 'Pressure_4_0', value=0.1052631578947368 (fixed), bounds=[-inf:inf]>),
#             ('Temperature_4_0',
#              <Parameter 'Temperature_4_0', value=298.15 (fixed), bounds=[-inf:inf]>),
#             ('baseline_a_4_0',
#              <Parameter 'baseline_a_4_0', value=5.7739485020759216e-05 +/- 6.39e-06, bounds=[-inf:inf]>),
#             ('molefraction_O2_4_0',
#              <Parameter 'molefraction_O2_4_0', value=0.002022 (fixed), bounds=[-inf:inf]>),
#             ('x_shift_4_0',
#              <Parameter 'x_shift_4_0', value=0.0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_3',
#              <Parameter 'nu_1_line_3', value=13154.18 (fixed), bounds=[-inf:inf]>),
#             ('nu_2_line_3',
#              <Parameter 'nu_2_line_3', value=13154.18 (fixed), bounds=[-inf:inf]>),
#             ('nu_3_line_3',
#              <Parameter 'nu_3_line_3', value=13154.18 (fixed), bounds=[-inf:inf]>),
#             ('nu_4_line_3',
#              <Parameter 'nu_4_line_3', value=13154.18 (fixed), bounds=[-inf:inf]>),
#             ('sw_1_line_3',
#              <Parameter 'sw_1_line_3', value=4.369 (fixed), bounds=[-inf:inf]>),
#             ('sw_2_line_3',
#              <Parameter 'sw_2_line_3', value=4.369 (fixed), bounds=[-inf:inf]>),
#             ('sw_3_line_3',
#              <Parameter 'sw_3_line_3', value=4.369 (fixed), bounds=[-inf:inf]>),
#             ('sw_4_line_3',
#              <Parameter 'sw_4_line_3', value=4.369 (fixed), bounds=[-inf:inf]>),
#             ('gamma0_air_line_3',
#              <Parameter 'gamma0_air_line_3', value=0.04 (fixed), bounds=[-inf:inf]>),
#             ('delta0_air_line_3',
#              <Parameter 'delta0_air_line_3', value=-0.007977 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_3',
#              <Parameter 'nuVC_air_line_3', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_3',
#              <Parameter 'SD_gamma_air_line_3', value=0.1 (fixed), bounds=[0:inf]>),
#             ('SD_delta_air_line_3',
#              <Parameter 'SD_delta_air_line_3', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_3',
#              <Parameter 'eta_air_line_3', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_3',
#              <Parameter 'y_air_296_line_3', value=0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_12',
#              <Parameter 'nu_1_line_12', value=13156.280003341266 +/- 5.89e-06, bounds=[-inf:inf]>),
#             ('nu_2_line_12',
#              <Parameter 'nu_2_line_12', value=13156.279989113718 +/- 3.21e-06, bounds=[-inf:inf]>),
#             ('nu_3_line_12',
#              <Parameter 'nu_3_line_12', value=13156.279986354077 +/- 2.33e-06, bounds=[-inf:inf]>),
#             ('nu_4_line_12',
#              <Parameter 'nu_4_line_12', value=13156.280007105943 +/- 1.9e-06, bounds=[-inf:inf]>),
#             ('sw_1_line_12',
#              <Parameter 'sw_1_line_12', value=4.799476825117282 +/- 0.00159, bounds=[-inf:inf]>),
#             ('sw_2_line_12',
#              <Parameter 'sw_2_line_12', value=4.795311224204903 +/- 0.000889, bounds=[-inf:inf]>),
#             ('sw_3_line_12',
#              <Parameter 'sw_3_line_12', value=4.798813332823055 +/- 0.000747, bounds=[-inf:inf]>),
#             ('sw_4_line_12',
#              <Parameter 'sw_4_line_12', value=4.79727752353463 +/- 0.000762, bounds=[-inf:inf]>),
#             ('gamma0_air_line_12',
#              <Parameter 'gamma0_air_line_12', value=0.03976750026189404 +/- 4.18e-05, bounds=[-inf:inf]>),
#             ('delta0_air_line_12',
#              <Parameter 'delta0_air_line_12', value=-0.007967 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_12',
#              <Parameter 'nuVC_air_line_12', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_12',
#              <Parameter 'SD_gamma_air_line_12', value=0.07315372172489165 +/- 0.000817, bounds=[0:inf]>),
#             ('SD_delta_air_line_12',
#              <Parameter 'SD_delta_air_line_12', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_12',
#              <Parameter 'eta_air_line_12', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_12',
#              <Parameter 'y_air_296_line_12', value=0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_15',
#              <Parameter 'nu_1_line_15', value=13156.62001362835 +/- 9e-06, bounds=[-inf:inf]>),
#             ('nu_2_line_15',
#              <Parameter 'nu_2_line_15', value=13156.619992316382 +/- 4.9e-06, bounds=[-inf:inf]>),
#             ('nu_3_line_15',
#              <Parameter 'nu_3_line_15', value=13156.620009761255 +/- 3.55e-06, bounds=[-inf:inf]>),
#             ('nu_4_line_15',
#              <Parameter 'nu_4_line_15', value=13156.62001227502 +/- 2.88e-06, bounds=[-inf:inf]>),
#             ('sw_1_line_15',
#              <Parameter 'sw_1_line_15', value=3.1228539760829985 +/- 0.00159, bounds=[-inf:inf]>),
#             ('sw_2_line_15',
#              <Parameter 'sw_2_line_15', value=3.1229082890744526 +/- 0.000886, bounds=[-inf:inf]>),
#             ('sw_3_line_15',
#              <Parameter 'sw_3_line_15', value=3.125862152342905 +/- 0.000744, bounds=[-inf:inf]>),
#             ('sw_4_line_15',
#              <Parameter 'sw_4_line_15', value=3.1257546394753484 +/- 0.00076, bounds=[-inf:inf]>),
#             ('gamma0_air_line_15',
#              <Parameter 'gamma0_air_line_15', value=0.03987527839046014 +/- 6.4e-05, bounds=[-inf:inf]>),
#             ('delta0_air_line_15',
#              <Parameter 'delta0_air_line_15', value=-0.0085469999999999 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_15',
#              <Parameter 'nuVC_air_line_15', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_15',
#              <Parameter 'SD_gamma_air_line_15', value=0.09409371181555914 +/- 0.00122, bounds=[0:inf]>),
#             ('SD_delta_air_line_15',
#              <Parameter 'SD_delta_air_line_15', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_15',
#              <Parameter 'eta_air_line_15', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_15',
#              <Parameter 'y_air_296_line_15', value=0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_27',
#              <Parameter 'nu_1_line_27', value=13158.68 (fixed), bounds=[-inf:inf]>),
#             ('nu_2_line_27',
#              <Parameter 'nu_2_line_27', value=13158.68 (fixed), bounds=[-inf:inf]>),
#             ('nu_3_line_27',
#              <Parameter 'nu_3_line_27', value=13158.68 (fixed), bounds=[-inf:inf]>),
#             ('nu_4_line_27',
#              <Parameter 'nu_4_line_27', value=13158.68 (fixed), bounds=[-inf:inf]>),
#             ('sw_1_line_27',
#              <Parameter 'sw_1_line_27', value=2.083 (fixed), bounds=[-inf:inf]>),
#             ('sw_2_line_27',
#              <Parameter 'sw_2_line_27', value=2.083 (fixed), bounds=[-inf:inf]>),
#             ('sw_3_line_27',
#              <Parameter 'sw_3_line_27', value=2.083 (fixed), bounds=[-inf:inf]>),
#             ('sw_4_line_27',
#              <Parameter 'sw_4_line_27', value=2.083 (fixed), bounds=[-inf:inf]>),
#             ('gamma0_air_line_27',
#              <Parameter 'gamma0_air_line_27', value=0.04 (fixed), bounds=[-inf:inf]>),
#             ('delta0_air_line_27',
#              <Parameter 'delta0_air_line_27', value=-0.0087411 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_27',
#              <Parameter 'nuVC_air_line_27', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_27',
#              <Parameter 'SD_gamma_air_line_27', value=0.09 (fixed), bounds=[0:inf]>),
#             ('SD_delta_air_line_27',
#              <Parameter 'SD_delta_air_line_27', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_27',
#              <Parameter 'eta_air_line_27', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_27',
#              <Parameter 'y_air_296_line_27', value=0 (fixed), bounds=[-inf:inf]>),
#             ('nu_1_line_28',
#              <Parameter 'nu_1_line_28', value=13158.74 (fixed), bounds=[-inf:inf]>),
#             ('nu_2_line_28',
#              <Parameter 'nu_2_line_28', value=13158.74 (fixed), bounds=[-inf:inf]>),
#             ('nu_3_line_28',
#              <Parameter 'nu_3_line_28', value=13158.74 (fixed), bounds=[-inf:inf]>),
#             ('nu_4_line_28',
#              <Parameter 'nu_4_line_28', value=13158.74 (fixed), bounds=[-inf:inf]>),
#             ('sw_1_line_28',
#              <Parameter 'sw_1_line_28', value=3.399 (fixed), bounds=[-inf:inf]>),
#             ('sw_2_line_28',
#              <Parameter 'sw_2_line_28', value=3.399 (fixed), bounds=[-inf:inf]>),
#             ('sw_3_line_28',
#              <Parameter 'sw_3_line_28', value=3.399 (fixed), bounds=[-inf:inf]>),
#             ('sw_4_line_28',
#              <Parameter 'sw_4_line_28', value=3.399 (fixed), bounds=[-inf:inf]>),
#             ('gamma0_air_line_28',
#              <Parameter 'gamma0_air_line_28', value=0.04 (fixed), bounds=[-inf:inf]>),
#             ('delta0_air_line_28',
#              <Parameter 'delta0_air_line_28', value=-0.008568 (fixed), bounds=[-inf:inf]>),
#             ('nuVC_air_line_28',
#              <Parameter 'nuVC_air_line_28', value=0 (fixed), bounds=[-inf:inf]>),
#             ('SD_gamma_air_line_28',
#              <Parameter 'SD_gamma_air_line_28', value=0.1 (fixed), bounds=[0:inf]>),
#             ('SD_delta_air_line_28',
#              <Parameter 'SD_delta_air_line_28', value=0 (fixed), bounds=[-inf:inf]>),
#             ('eta_air_line_28',
#              <Parameter 'eta_air_line_28', value=0 (fixed), bounds=[-inf:inf]>),
#             ('y_air_296_line_28',
#              <Parameter 'y_air_296_line_28', value=0 (fixed), bounds=[-inf:inf]>)])
