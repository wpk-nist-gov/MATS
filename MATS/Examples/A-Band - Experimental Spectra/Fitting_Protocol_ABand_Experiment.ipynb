# %% [markdown]
# # A-Band Fitting Using HAPI MultiSpectrum fitting
# * Loads packages
# * Defines Spectra and Dataset
# * Generates parameter and baseline linelists
# * Fits Data

# %%
## Multi- Spectrum Fitting by Segment

import numpy as np
import pandas as pd
import qgrid
import os, sys
import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

#sys.path.append(r'C:\Users\ema3\Documents\MATS\MATS')# set location of HAPI.py module

from MATS.hapi import *
from MATS.MATS import *

import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
sns.set_context("poster")
# Out:
# HAPI version: 1.1.0.9.6
# To get the most up-to-date version please check http://hitran.org/hapi
# ATTENTION: Python versions of partition sums from TIPS-2017 are now available in HAPI code
#
#            It is free to use HAPI. If you use HAPI in your research or software development,
#            please cite it using the following reference:
#            R.V. Kochanov, I.E. Gordon, L.S. Rothman, P. Wcislo, C. Hill, J.S. Wilzewski,
#            HITRAN Application Programming Interface (HAPI): A comprehensive approach
#            to working with spectroscopic data, J. Quant. Spectrosc. Radiat. Transfer 177, 15-30 (2016)
#            DOI: 10.1016/j.jqsrt.2016.03.005

# %% [markdown]
# ## Load Spectrum

# %% [raw]
# path = r'C:\Users\ema3\Documents\MATS\MATS\Examples\A-Band - Experimental Spectra'
# os.chdir(path)

# %%
#Generic Fit Parameters
wave_range = 1.5 #range outside of experimental x-range to simulate
IntensityThreshold = 1e-30 #intensities must be above this value to be simulated
Fit_Intensity = 1e-24 #intensities must be above this value for the line to be fit
order_baseline_fit = 1
tau_column = 'Corrected Tau (us)' # Mean tau/us
freq_column = 'Total Frequency (Detuning)' # Total Frequency /MHz
pressure_column = 'Cavity Pressure /Torr'
temperature_column = 'Cavity Temperature Side 2 /C'
tau_stats_column = 'tau rel. std. dev./%'


#Define all Spectra individually
spec_1 = Spectrum('190510_2per_43_forfit', 
                        molefraction = { 7 :0.01949}, natural_abundance = True, diluent = 'air', 
                        etalons = {1:[0.001364, 1.271443]}, 
                        input_freq = True, frequency_column = freq_column,
                        input_tau = True, tau_column = tau_column, tau_stats_column = tau_stats_column, 
                        pressure_column = pressure_column, temperature_column = temperature_column, 
                        nominal_temperature = 296, x_shift = 0.00)
spec_2 = Spectrum('190510_2per_55_forfit', 
                        molefraction = { 7 : 0.01949}, natural_abundance = True, diluent = 'air', 
                        etalons = {1:[0.001364, 1.271443]}, 
                        input_freq = True, frequency_column = freq_column,
                        input_tau = True, tau_column = tau_column, tau_stats_column = tau_stats_column, 
                        pressure_column = pressure_column, temperature_column = temperature_column, 
                        nominal_temperature = 296, x_shift = 0.00)
spec_3 = Spectrum('190513_2per_82_forfit', 
                        molefraction = { 7 :0.01949}, natural_abundance = True, diluent = 'air', 
                        etalons = {1:[0.001364, 1.271443]}, 
                        input_freq = True, frequency_column = freq_column,
                        input_tau = True, tau_column = tau_column, tau_stats_column = tau_stats_column, 
                        pressure_column = pressure_column, temperature_column = temperature_column, 
                        nominal_temperature = 296, x_shift = 0.00)
spec_4 = Spectrum('190514_2per_126_forfit', 
                        molefraction = { 7 :0.01949}, natural_abundance = True, diluent = 'air', 
                        etalons = {1:[0.001364, 1.271443]}, 
                        input_freq = True, frequency_column = freq_column,
                        input_tau = True, tau_column = tau_column, tau_stats_column = tau_stats_column, 
                        pressure_column = pressure_column, temperature_column = temperature_column, 
                        nominal_temperature = 296, x_shift = 0.00)



spec_1.plot_wave_alpha()

# %% [markdown]
# ## Construct Dataset

# %% [raw]
# #Read in Possible linelists
# hapi = r'C:\Users\ema3\Documents\MATS\MATS\Linelists'
# os.chdir(hapi)
# PARAM_LINELIST = pd.read_csv('O2_ABand_Drouin_2017_linelist.csv')

# %%
from MATS.exampledata import exampledata

# %%
PARAM_LINELIST = exampledata.O2_ABand_Drouin_2017_linelist

# %%
#Add all spectrum to a Dataset object
#os.chdir(path)
SPECTRA = Dataset([spec_1, spec_2, spec_3, spec_4], 'Line Intensity',PARAM_LINELIST ,baseline_order = order_baseline_fit)

#Generate Baseline Parameter list based on number of etalons in spectra definitions and baseline order
BASE_LINELIST = SPECTRA.generate_baseline_paramlist()
#BASE_LINELIST = pd.read_csv('Line Intensity_baseline_paramlist.csv')

# %% [markdown]
# ## Generate Fit Parameter Files

# %%
# os.chdir(path)
# Set-up for Fitting
#lineprofile = 'NGP' #VP, SDVP, NGP, SDNGP, HTP


  

FITPARAMS = Generate_FitParam_File(SPECTRA, PARAM_LINELIST, BASE_LINELIST, lineprofile = 'SDVP', linemixing = False, 
                                  fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, sim_window = wave_range,
                                  nu_constrain = False, sw_constrain = False, gamma0_constrain = True, delta0_constrain = True, 
                                   aw_constrain = True, as_constrain = True, 
                                   nuVC_constrain = True, eta_constrain =True, linemixing_constrain = True)
                                  #additional_columns = ['trans_id', 'local_lower_quanta', 'm'])

FITPARAMS.generate_fit_param_linelist_from_linelist(vary_nu = {7:{1:True, 2:False, 3:False}}, vary_sw = {7:{1:True, 2:False, 3:False}},
                                                    vary_gamma0 = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma0 = {7:{1:True}}, 
                                                    vary_delta0 = {7:{1: False, 2:False, 3: False}, 1:{1:False}}, vary_n_delta0 = {7:{1:True}}, 
                                                    vary_aw = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma2 = {7:{1:False}}, 
                                                    vary_as = {}, vary_n_delta2 = {7:{1:False}}, 
                                                    vary_nuVC = {7:{1:False}}, vary_n_nuVC = {7:{1:False}},
                                                    vary_eta = {}, vary_linemixing = {7:{1:False}})

FITPARAMS.generate_fit_baseline_linelist(vary_baseline = True, vary_molefraction = {7:False, 1:False}, vary_xshift = False, 
                                      vary_etalon_amp= True, vary_etalon_period= False, vary_etalon_phase= True)
# Out:
#                  Segment Number  Pressure  Pressure_err  Pressure_vary  \
# Spectrum Number
# 1.0                         1.0  0.079111             0          False
# 2.0                         1.0  0.065558             0          False
# 3.0                         1.0  0.046017             0          False
# 4.0                         1.0  0.024884             0          False
#
#                  Temperature  Temperature_err  Temperature_vary  baseline_a  \
# Spectrum Number
# 1.0               297.903746                0             False         0.0
# 2.0               297.908245                0             False         0.0
# 3.0               297.876303                0             False         0.0
# 4.0               297.864910                0             False         0.0
#
#                  baseline_a_err  baseline_a_vary  ...  etalon_1_period_vary  \
# Spectrum Number                                   ...
# 1.0                           0             True  ...                 False
# 2.0                           0             True  ...                 False
# 3.0                           0             True  ...                 False
# 4.0                           0             True  ...                 False
#
#                  etalon_1_phase  etalon_1_phase_err  etalon_1_phase_vary  \
# Spectrum Number
# 1.0                         0.0                   0                 True
# 2.0                         0.0                   0                 True
# 3.0                         0.0                   0                 True
# 4.0                         0.0                   0                 True
#
#                  molefraction_O2  molefraction_O2_err  molefraction_O2_vary  \
# Spectrum Number
# 1.0                      0.01949                    0                 False
# 2.0                      0.01949                    0                 False
# 3.0                      0.01949                    0                 False
# 4.0                      0.01949                    0                 False
#
#                  x_shift  x_shift_err  x_shift_vary
# Spectrum Number
# 1.0                  0.0            0         False
# 2.0                  0.0            0         False
# 3.0                  0.0            0         False
# 4.0                  0.0            0         False
#
# [4 rows x 28 columns]

# %%
# os.chdir(path)   
fit_data = Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity, weight_spectra = False,
                baseline_limit = False, baseline_limit_factor = 10, 
                molefraction_limit = False, molefraction_limit_factor = 1.1, 
                etalon_limit = False, etalon_limit_factor = 2, #phase is constrained to +/- 2pi, 
                x_shift_limit = False, x_shift_limit_magnitude = 0.5, 
                nu_limit = True, nu_limit_magnitude = 0.1, 
                sw_limit = True, sw_limit_factor = 2, 
                gamma0_limit = False, gamma0_limit_factor = 3, n_gamma0_limit= False, n_gamma0_limit_factor = 50, 
                delta0_limit = False, delta0_limit_factor = 2, n_delta0_limit = False, n_delta0_limit_factor = 50, 
                SD_gamma_limit = False, SD_gamma_limit_factor = 2, n_gamma2_limit = False, n_gamma2_limit_factor = 50, 
                SD_delta_limit = False, SD_delta_limit_factor = 50, n_delta2_limit = False, n_delta2_limit_factor = 50, 
                nuVC_limit = False, nuVC_limit_factor = 2, n_nuVC_limit = False, n_nuVC_limit_factor = 50, 
                eta_limit = False, eta_limit_factor = 50, linemixing_limit = False, linemixing_limit_factor = 50)
params = fit_data.generate_params()



for param in params:
    if 'SD_gamma' in param:
        if params[param].vary == True:
            params[param].set(min = 0.01, max = 0.25)
    if 'etalon_1_amp' in param:
        if param != 'etalon_1_amp_1_1':
            params[param].set(expr='etalon_1_amp_1_1')
            
        


result = fit_data.fit_data(params, wing_cutoff = 25)
print (result.params.pretty_print())

fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
SPECTRA.plot_model_residuals()
# Out:
# Name                     Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_1           0.07911     -inf      inf        0    False     None     None
# Pressure_2_1           0.06556     -inf      inf        0    False     None     None
# Pressure_3_1           0.04602     -inf      inf        0    False     None     None
# Pressure_4_1           0.02488     -inf      inf        0    False     None     None
# SD_delta_air_line_1          0     -inf      inf        0    False     None     None
# SD_delta_air_line_10         0     -inf      inf        0    False     None     None
# SD_delta_air_line_13         0     -inf      inf        0    False     None     None
# SD_delta_air_line_25         0     -inf      inf        0    False     None     None
# SD_delta_air_line_26         0     -inf      inf        0    False     None     None
# SD_gamma_air_line_1        0.1     -inf      inf        0    False     None     None
# SD_gamma_air_line_10    0.1124     0.01     0.25 0.0009002     True     None     None
# SD_gamma_air_line_13    0.1306     0.01     0.25 0.001206     True     None     None
# SD_gamma_air_line_25      0.09     -inf      inf        0    False     None     None
# SD_gamma_air_line_26       0.1     -inf      inf        0    False     None     None
# Temperature_1_1          297.9     -inf      inf        0    False     None     None
# Temperature_2_1          297.9     -inf      inf        0    False     None     None
# Temperature_3_1          297.9     -inf      inf        0    False     None     None
# Temperature_4_1          297.9     -inf      inf        0    False     None     None
# baseline_a_1_1           2.958     -inf      inf 0.0001147     True     None     None
# baseline_a_2_1           2.959     -inf      inf 0.0001105     True     None     None
# baseline_a_3_1           2.953     -inf      inf 0.0001124     True     None     None
# baseline_a_4_1            2.95     -inf      inf 0.0001165     True     None     None
# baseline_b_1_1        0.002031     -inf      inf 0.0001246     True     None     None
# baseline_b_2_1        0.001985     -inf      inf 0.0001194     True     None     None
# baseline_b_3_1        0.001964     -inf      inf 0.0001256     True     None     None
# baseline_b_4_1        0.001777     -inf      inf 0.0001409     True     None     None
# delta0_air_line_1     -0.007977     -inf      inf        0    False     None     None
# delta0_air_line_10    -0.007967     -inf      inf        0    False     None     None
# delta0_air_line_13    -0.008547     -inf      inf        0    False     None     None
# delta0_air_line_25    -0.008741     -inf      inf        0    False     None     None
# delta0_air_line_26    -0.008568     -inf      inf        0    False     None     None
# eta_air_line_1               0     -inf      inf        0    False     None     None
# eta_air_line_10              0     -inf      inf        0    False     None     None
# eta_air_line_13              0     -inf      inf        0    False     None     None
# eta_air_line_25              0     -inf      inf        0    False     None     None
# eta_air_line_26              0     -inf      inf        0    False     None     None
# etalon_1_amp_1_1       0.00165     -inf      inf 4.28e-05     True     None     None
# etalon_1_amp_2_1       0.00165     -inf      inf 4.28e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_3_1       0.00165     -inf      inf 4.28e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_4_1       0.00165     -inf      inf 4.28e-05    False etalon_1_amp_1_1     None
# etalon_1_period_1_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_2_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_3_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_4_1      1.271     -inf      inf        0    False     None     None
# etalon_1_phase_1_1     -0.7341     -inf      inf  0.05247     True     None     None
# etalon_1_phase_2_1     -0.4803     -inf      inf  0.04848     True     None     None
# etalon_1_phase_3_1      -1.418     -inf      inf  0.05245     True     None     None
# etalon_1_phase_4_1      -1.647     -inf      inf  0.05185     True     None     None
# gamma0_air_line_1         0.04     -inf      inf        0    False     None     None
# gamma0_air_line_10     0.04487     -inf      inf 5.335e-05     True     None     None
# gamma0_air_line_13     0.04331     -inf      inf 8.074e-05     True     None     None
# gamma0_air_line_25        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_26        0.04     -inf      inf        0    False     None     None
# molefraction_O2_1_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_2_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_3_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_4_1    0.01949     -inf      inf        0    False     None     None
# nuVC_air_line_1              0     -inf      inf        0    False     None     None
# nuVC_air_line_10             0     -inf      inf        0    False     None     None
# nuVC_air_line_13             0     -inf      inf        0    False     None     None
# nuVC_air_line_25             0     -inf      inf        0    False     None     None
# nuVC_air_line_26             0     -inf      inf        0    False     None     None
# nu_1_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_1_line_10          1.316e+04 1.316e+04 1.316e+04 2.103e-06     True     None     None
# nu_1_line_13          1.316e+04 1.316e+04 1.316e+04 2.54e-06     True     None     None
# nu_1_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_1_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_2_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_2_line_10          1.316e+04 1.316e+04 1.316e+04 2.324e-06     True     None     None
# nu_2_line_13          1.316e+04 1.316e+04 1.316e+04 2.909e-06     True     None     None
# nu_2_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_2_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_3_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_3_line_10          1.316e+04 1.316e+04 1.316e+04 2.186e-06     True     None     None
# nu_3_line_13          1.316e+04 1.316e+04 1.316e+04 4.036e-06     True     None     None
# nu_3_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_3_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_4_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_4_line_10          1.316e+04 1.316e+04 1.316e+04 4.455e-06     True     None     None
# nu_4_line_13          1.316e+04 1.316e+04 1.316e+04 6.806e-06     True     None     None
# nu_4_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_4_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# sw_1_line_1               4.37    2.185     8.74        0    False     None     None
# sw_1_line_10             4.732      2.4      9.6 0.0009325     True     None     None
# sw_1_line_13             3.086     1.56     6.24 0.0007791     True     None     None
# sw_1_line_25              2.08     1.04     4.16        0    False     None     None
# sw_1_line_26               3.4      1.7      6.8        0    False     None     None
# sw_2_line_1               4.37    2.185     8.74        0    False     None     None
# sw_2_line_10              4.75      2.4      9.6 0.0007537     True     None     None
# sw_2_line_13             3.091     1.56     6.24 0.0007396     True     None     None
# sw_2_line_25              2.08     1.04     4.16        0    False     None     None
# sw_2_line_26               3.4      1.7      6.8        0    False     None     None
# sw_3_line_1               4.37    2.185     8.74        0    False     None     None
# sw_3_line_10             4.742      2.4      9.6 0.0008072     True     None     None
# sw_3_line_13             3.094     1.56     6.24 0.0008104     True     None     None
# sw_3_line_25              2.08     1.04     4.16        0    False     None     None
# sw_3_line_26               3.4      1.7      6.8        0    False     None     None
# sw_4_line_1               4.37    2.185     8.74        0    False     None     None
# sw_4_line_10             4.798      2.4      9.6 0.001252     True     None     None
# sw_4_line_13             3.117     1.56     6.24 0.001272     True     None     None
# sw_4_line_25              2.08     1.04     4.16        0    False     None     None
# sw_4_line_26               3.4      1.7      6.8        0    False     None     None
# x_shift_1_1                  0     -inf      inf        0    False     None     None
# x_shift_2_1                  0     -inf      inf        0    False     None     None
# x_shift_3_1                  0     -inf      inf        0    False     None     None
# x_shift_4_1                  0     -inf      inf        0    False     None     None
# y_air_296_line_1             0     -inf      inf        0    False     None     None
# y_air_296_line_10            0     -inf      inf        0    False     None     None
# y_air_296_line_13            0     -inf      inf        0    False     None     None
# y_air_296_line_25            0     -inf      inf        0    False     None     None
# y_air_296_line_26            0     -inf      inf        0    False     None     None
# None

# %%
spec_3.fft_spectrum()
# Out:
#     Period (cm)  Amplitude     Phase  Freq (cm-1)
# 0      2.542886   0.000214  0.171578     0.393254
# 1      1.271443   0.000175 -2.956286     0.786508
# 2     55.307760   0.000170 -3.084972     0.018081
# 3      8.264378   0.000159  0.413799     0.121001
# 4      6.357214   0.000146  0.135501     0.157302
# 5     14.621592   0.000144 -3.042250     0.068392
# 6     38.143283   0.000143  2.264378     0.026217
# 7     10.807263   0.000142  3.127966     0.092530
# 8     35.600397   0.000141  1.102780     0.028090
# 9     46.407660   0.000140  0.440692     0.021548
# 10    33.057512   0.000136 -1.330423     0.030250
# 11    15.893034   0.000135 -2.563447     0.062921
# 12    12.078706   0.000134 -0.580154     0.082790
# 13    63.572138   0.000123  0.241773     0.015730
# 14    10.171542   0.000122  0.208993     0.098314
# 15    43.864775   0.000122 -1.375508     0.022797
# 16    41.321889   0.000122  2.473382     0.024200
# 17     6.992935   0.000119  2.662990     0.143001
# 18    47.043382   0.000116 -0.950786     0.021257
# 19    22.250248   0.000112 -2.107469     0.044943
# 20    29.878905   0.000109 -1.267243     0.033468
# /Users/wpk/Documents/python/projects/MATS/MATS/Spectrum.py:413: RuntimeWarning: divide by zero encountered in true_divide
#   FFT['Freq (cm-1)'] = 1 / fft_freq
# /Users/wpk/Documents/python/projects/MATS/MATS/Spectrum.py:418: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(1 / fft_freq, fft_amplitude, '-')

# %%
# Weight Using Stats Column Only


# os.chdir(path)
# Set-up for Fitting
#lineprofile = 'NGP' #VP, SDVP, NGP, SDNGP, HTP


  

FITPARAMS = Generate_FitParam_File(SPECTRA, PARAM_LINELIST, BASE_LINELIST, lineprofile = 'SDVP', linemixing = True, 
                                  fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, sim_window = wave_range,
                                  nu_constrain = False, sw_constrain = False, gamma0_constrain = True, delta0_constrain = True, 
                                   aw_constrain = True, as_constrain = True, 
                                   nuVC_constrain = True, eta_constrain =True, linemixing_constrain = True)
                                  #additional_columns = ['trans_id', 'local_lower_quanta', 'm'])

FITPARAMS.generate_fit_param_linelist_from_linelist(vary_nu = {7:{1:True, 2:False, 3:False}}, vary_sw = {7:{1:True, 2:False, 3:False}},
                                                    vary_gamma0 = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma0 = {7:{1:True}}, 
                                                    vary_delta0 = {7:{1: False, 2:False, 3: False}, 1:{1:False}}, vary_n_delta0 = {7:{1:True}}, 
                                                    vary_aw = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma2 = {7:{1:False}}, 
                                                    vary_as = {}, vary_n_delta2 = {7:{1:False}}, 
                                                    vary_nuVC = {7:{1:False}}, vary_n_nuVC = {7:{1:False}},
                                                    vary_eta = {}, vary_linemixing = {7:{1:False}})

FITPARAMS.generate_fit_baseline_linelist(vary_baseline = True, vary_molefraction = {7:False, 1:False}, vary_xshift = False, 
                                      vary_etalon_amp= True, vary_etalon_period= False, vary_etalon_phase= True)


# os.chdir(path)   
fit_data = Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity, weight_spectra = True,
                baseline_limit = False, baseline_limit_factor = 10, 
                molefraction_limit = False, molefraction_limit_factor = 1.1, 
                etalon_limit = False, etalon_limit_factor = 2, #phase is constrained to +/- 2pi, 
                x_shift_limit = False, x_shift_limit_magnitude = 0.5, 
                nu_limit = True, nu_limit_magnitude = 0.1, 
                sw_limit = True, sw_limit_factor = 2, 
                gamma0_limit = False, gamma0_limit_factor = 3, n_gamma0_limit= False, n_gamma0_limit_factor = 50, 
                delta0_limit = False, delta0_limit_factor = 2, n_delta0_limit = False, n_delta0_limit_factor = 50, 
                SD_gamma_limit = False, SD_gamma_limit_factor = 2, n_gamma2_limit = False, n_gamma2_limit_factor = 50, 
                SD_delta_limit = False, SD_delta_limit_factor = 50, n_delta2_limit = False, n_delta2_limit_factor = 50, 
                nuVC_limit = False, nuVC_limit_factor = 2, n_nuVC_limit = False, n_nuVC_limit_factor = 50, 
                eta_limit = False, eta_limit_factor = 50, linemixing_limit = False, linemixing_limit_factor = 50)
params = fit_data.generate_params()



for param in params:
    if 'SD_gamma' in param:
        if params[param].vary == True:
            params[param].set(min = 0.01, max = 0.25)
    if 'etalon_1_amp' in param:
        if param != 'etalon_1_amp_1_1':
            params[param].set(expr='etalon_1_amp_1_1')
            
        


result = fit_data.fit_data(params, wing_cutoff = 25)
print (result.params.pretty_print())

fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
SPECTRA.plot_model_residuals()
# Out:
# Name                     Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_1           0.07911     -inf      inf        0    False     None     None
# Pressure_2_1           0.06556     -inf      inf        0    False     None     None
# Pressure_3_1           0.04602     -inf      inf        0    False     None     None
# Pressure_4_1           0.02488     -inf      inf        0    False     None     None
# SD_delta_air_line_1          0     -inf      inf        0    False     None     None
# SD_delta_air_line_10         0     -inf      inf        0    False     None     None
# SD_delta_air_line_13         0     -inf      inf        0    False     None     None
# SD_delta_air_line_25         0     -inf      inf        0    False     None     None
# SD_delta_air_line_26         0     -inf      inf        0    False     None     None
# SD_gamma_air_line_1        0.1     -inf      inf        0    False     None     None
# SD_gamma_air_line_10    0.1069     0.01     0.25 0.001312     True     None     None
# SD_gamma_air_line_13    0.1271     0.01     0.25 0.001549     True     None     None
# SD_gamma_air_line_25      0.09     -inf      inf        0    False     None     None
# SD_gamma_air_line_26       0.1     -inf      inf        0    False     None     None
# Temperature_1_1          297.9     -inf      inf        0    False     None     None
# Temperature_2_1          297.9     -inf      inf        0    False     None     None
# Temperature_3_1          297.9     -inf      inf        0    False     None     None
# Temperature_4_1          297.9     -inf      inf        0    False     None     None
# baseline_a_1_1           2.958     -inf      inf 9.539e-05     True     None     None
# baseline_a_2_1            2.96     -inf      inf 9.106e-05     True     None     None
# baseline_a_3_1           2.953     -inf      inf 9.467e-05     True     None     None
# baseline_a_4_1            2.95     -inf      inf 9.328e-05     True     None     None
# baseline_b_1_1        0.001995     -inf      inf 0.0001025     True     None     None
# baseline_b_2_1          0.0019     -inf      inf 9.693e-05     True     None     None
# baseline_b_3_1        0.001954     -inf      inf 0.0001066     True     None     None
# baseline_b_4_1         0.00181     -inf      inf 0.0001125     True     None     None
# delta0_air_line_1     -0.007977     -inf      inf        0    False     None     None
# delta0_air_line_10    -0.007967     -inf      inf        0    False     None     None
# delta0_air_line_13    -0.008547     -inf      inf        0    False     None     None
# delta0_air_line_25    -0.008741     -inf      inf        0    False     None     None
# delta0_air_line_26    -0.008568     -inf      inf        0    False     None     None
# eta_air_line_1               0     -inf      inf        0    False     None     None
# eta_air_line_10              0     -inf      inf        0    False     None     None
# eta_air_line_13              0     -inf      inf        0    False     None     None
# eta_air_line_25              0     -inf      inf        0    False     None     None
# eta_air_line_26              0     -inf      inf        0    False     None     None
# etalon_1_amp_1_1      0.001619     -inf      inf 3.502e-05     True     None     None
# etalon_1_amp_2_1      0.001619     -inf      inf 3.502e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_3_1      0.001619     -inf      inf 3.502e-05    False etalon_1_amp_1_1     None
# etalon_1_amp_4_1      0.001619     -inf      inf 3.502e-05    False etalon_1_amp_1_1     None
# etalon_1_period_1_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_2_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_3_1      1.271     -inf      inf        0    False     None     None
# etalon_1_period_4_1      1.271     -inf      inf        0    False     None     None
# etalon_1_phase_1_1     -0.7616     -inf      inf  0.04452     True     None     None
# etalon_1_phase_2_1     -0.5136     -inf      inf  0.04042     True     None     None
# etalon_1_phase_3_1      -1.414     -inf      inf  0.04624     True     None     None
# etalon_1_phase_4_1      -1.667     -inf      inf  0.04234     True     None     None
# gamma0_air_line_1         0.04     -inf      inf        0    False     None     None
# gamma0_air_line_10     0.04463     -inf      inf 5.439e-05     True     None     None
# gamma0_air_line_13      0.0432     -inf      inf 7.61e-05     True     None     None
# gamma0_air_line_25        0.04     -inf      inf        0    False     None     None
# gamma0_air_line_26        0.04     -inf      inf        0    False     None     None
# molefraction_O2_1_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_2_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_3_1    0.01949     -inf      inf        0    False     None     None
# molefraction_O2_4_1    0.01949     -inf      inf        0    False     None     None
# nuVC_air_line_1              0     -inf      inf        0    False     None     None
# nuVC_air_line_10             0     -inf      inf        0    False     None     None
# nuVC_air_line_13             0     -inf      inf        0    False     None     None
# nuVC_air_line_25             0     -inf      inf        0    False     None     None
# nuVC_air_line_26             0     -inf      inf        0    False     None     None
# nu_1_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_1_line_10          1.316e+04 1.316e+04 1.316e+04 2.887e-06     True     None     None
# nu_1_line_13          1.316e+04 1.316e+04 1.316e+04 4.175e-06     True     None     None
# nu_1_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_1_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_2_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_2_line_10          1.316e+04 1.316e+04 1.316e+04 4.399e-06     True     None     None
# nu_2_line_13          1.316e+04 1.316e+04 1.316e+04 4.757e-06     True     None     None
# nu_2_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_2_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_3_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_3_line_10          1.316e+04 1.316e+04 1.316e+04 5.24e-06     True     None     None
# nu_3_line_13          1.316e+04 1.316e+04 1.316e+04 5.245e-06     True     None     None
# nu_3_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_3_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_4_line_1           1.315e+04 1.315e+04 1.315e+04        0    False     None     None
# nu_4_line_10          1.316e+04 1.316e+04 1.316e+04 5.85e-06     True     None     None
# nu_4_line_13          1.316e+04 1.316e+04 1.316e+04 7.458e-06     True     None     None
# nu_4_line_25          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# nu_4_line_26          1.316e+04 1.316e+04 1.316e+04        0    False     None     None
# sw_1_line_1               4.37    2.185     8.74        0    False     None     None
# sw_1_line_10              4.73      2.4      9.6 0.001451     True     None     None
# sw_1_line_13             3.086     1.56     6.24 0.0009114     True     None     None
# sw_1_line_25              2.08     1.04     4.16        0    False     None     None
# sw_1_line_26               3.4      1.7      6.8        0    False     None     None
# sw_2_line_1               4.37    2.185     8.74        0    False     None     None
# sw_2_line_10             4.748      2.4      9.6 0.001114     True     None     None
# sw_2_line_13             3.091     1.56     6.24 0.0009295     True     None     None
# sw_2_line_25              2.08     1.04     4.16        0    False     None     None
# sw_2_line_26               3.4      1.7      6.8        0    False     None     None
# sw_3_line_1               4.37    2.185     8.74        0    False     None     None
# sw_3_line_10             4.742      2.4      9.6 0.001313     True     None     None
# sw_3_line_13             3.094     1.56     6.24 0.001045     True     None     None
# sw_3_line_25              2.08     1.04     4.16        0    False     None     None
# sw_3_line_26               3.4      1.7      6.8        0    False     None     None
# sw_4_line_1               4.37    2.185     8.74        0    False     None     None
# sw_4_line_10             4.797      2.4      9.6 0.001711     True     None     None
# sw_4_line_13             3.117     1.56     6.24 0.001426     True     None     None
# sw_4_line_25              2.08     1.04     4.16        0    False     None     None
# sw_4_line_26               3.4      1.7      6.8        0    False     None     None
# x_shift_1_1                  0     -inf      inf        0    False     None     None
# x_shift_2_1                  0     -inf      inf        0    False     None     None
# x_shift_3_1                  0     -inf      inf        0    False     None     None
# x_shift_4_1                  0     -inf      inf        0    False     None     None
# y_air_296_line_1      -0.00086     -inf      inf        0    False     None     None
# y_air_296_line_10     -0.00103     -inf      inf        0    False     None     None
# y_air_296_line_13     -0.00143     -inf      inf        0    False     None     None
# y_air_296_line_25     -0.00207     -inf      inf        0    False     None     None
# y_air_296_line_26     -0.00164     -inf      inf        0    False     None     None
# None

# %%
# Change the Weights of spectra and use stats column

spec_4.set_weight(0)

# os.chdir(path)
# Set-up for Fitting
#lineprofile = 'NGP' #VP, SDVP, NGP, SDNGP, HTP


  

FITPARAMS = Generate_FitParam_File(SPECTRA, PARAM_LINELIST, BASE_LINELIST, lineprofile = 'SDVP', linemixing = False, 
                                  fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, sim_window = wave_range,
                                  nu_constrain = False, sw_constrain = False, gamma0_constrain = True, delta0_constrain = True, 
                                   aw_constrain = True, as_constrain = True, 
                                   nuVC_constrain = True, eta_constrain =True, linemixing_constrain = True)
                                  #additional_columns = ['trans_id', 'local_lower_quanta', 'm'])

FITPARAMS.generate_fit_param_linelist_from_linelist(vary_nu = {7:{1:True, 2:False, 3:False}}, vary_sw = {7:{1:True, 2:False, 3:False}},
                                                    vary_gamma0 = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma0 = {7:{1:True}}, 
                                                    vary_delta0 = {7:{1: False, 2:False, 3: False}, 1:{1:False}}, vary_n_delta0 = {7:{1:True}}, 
                                                    vary_aw = {7:{1: True, 2:False, 3: False}, 1:{1:False}}, vary_n_gamma2 = {7:{1:False}}, 
                                                    vary_as = {}, vary_n_delta2 = {7:{1:False}}, 
                                                    vary_nuVC = {7:{1:False}}, vary_n_nuVC = {7:{1:False}},
                                                    vary_eta = {}, vary_linemixing = {7:{1:False}})

FITPARAMS.generate_fit_baseline_linelist(vary_baseline = True, vary_molefraction = {7:False, 1:False}, vary_xshift = False, 
                                      vary_etalon_amp= True, vary_etalon_period= False, vary_etalon_phase= True)


# os.chdir(path)   
fit_data = Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity, weight_spectra = True,
                baseline_limit = False, baseline_limit_factor = 10, 
                molefraction_limit = False, molefraction_limit_factor = 1.1, 
                etalon_limit = False, etalon_limit_factor = 2, #phase is constrained to +/- 2pi, 
                x_shift_limit = False, x_shift_limit_magnitude = 0.5, 
                nu_limit = True, nu_limit_magnitude = 0.1, 
                sw_limit = True, sw_limit_factor = 2, 
                gamma0_limit = False, gamma0_limit_factor = 3, n_gamma0_limit= False, n_gamma0_limit_factor = 50, 
                delta0_limit = False, delta0_limit_factor = 2, n_delta0_limit = False, n_delta0_limit_factor = 50, 
                SD_gamma_limit = False, SD_gamma_limit_factor = 2, n_gamma2_limit = False, n_gamma2_limit_factor = 50, 
                SD_delta_limit = False, SD_delta_limit_factor = 50, n_delta2_limit = False, n_delta2_limit_factor = 50, 
                nuVC_limit = False, nuVC_limit_factor = 2, n_nuVC_limit = False, n_nuVC_limit_factor = 50, 
                eta_limit = False, eta_limit_factor = 50, linemixing_limit = False, linemixing_limit_factor = 50)
params = fit_data.generate_params()



for param in params:
    if 'SD_gamma' in param:
        if params[param].vary == True:
            params[param].set(min = 0.01, max = 0.25)
    if 'etalon_1_amp' in param:
        if param != 'etalon_1_amp_1_1':
            params[param].set(expr='etalon_1_amp_1_1')
            
        


result = fit_data.fit_data(params, wing_cutoff = 25)
print (result.params.pretty_print())

fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
SPECTRA.plot_model_residuals()
# Out:
# Change the weight to a non-zero value or remove the spectrum from the dataset.  If the weight is 0, then the residuals returned for that spectrum will be 0.
# Name                     Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_1           0.07911     -inf      inf     None    False     None     None
# Pressure_2_1           0.06556     -inf      inf     None    False     None     None
# Pressure_3_1           0.04602     -inf      inf     None    False     None     None
# Pressure_4_1           0.02488     -inf      inf     None    False     None     None
# SD_delta_air_line_1          0     -inf      inf     None    False     None     None
# SD_delta_air_line_10         0     -inf      inf     None    False     None     None
# SD_delta_air_line_13         0     -inf      inf     None    False     None     None
# SD_delta_air_line_25         0     -inf      inf     None    False     None     None
# SD_delta_air_line_26         0     -inf      inf     None    False     None     None
# SD_gamma_air_line_1        0.1     -inf      inf     None    False     None     None
# SD_gamma_air_line_10    0.1066     0.01     0.25     None     True     None     None
# SD_gamma_air_line_13    0.1273     0.01     0.25     None     True     None     None
# SD_gamma_air_line_25      0.09     -inf      inf     None    False     None     None
# SD_gamma_air_line_26       0.1     -inf      inf     None    False     None     None
# Temperature_1_1          297.9     -inf      inf     None    False     None     None
# Temperature_2_1          297.9     -inf      inf     None    False     None     None
# Temperature_3_1          297.9     -inf      inf     None    False     None     None
# Temperature_4_1          297.9     -inf      inf     None    False     None     None
# baseline_a_1_1           2.958     -inf      inf     None     True     None     None
# baseline_a_2_1            2.96     -inf      inf     None     True     None     None
# baseline_a_3_1           2.953     -inf      inf     None     True     None     None
# baseline_a_4_1               0     -inf      inf     None     True     None     None
# baseline_b_1_1        0.001983     -inf      inf     None     True     None     None
# baseline_b_2_1        0.001899     -inf      inf     None     True     None     None
# baseline_b_3_1         0.00195     -inf      inf     None     True     None     None
# baseline_b_4_1               0     -inf      inf     None     True     None     None
# delta0_air_line_1     -0.007977     -inf      inf     None    False     None     None
# delta0_air_line_10    -0.007967     -inf      inf     None    False     None     None
# delta0_air_line_13    -0.008547     -inf      inf     None    False     None     None
# delta0_air_line_25    -0.008741     -inf      inf     None    False     None     None
# delta0_air_line_26    -0.008568     -inf      inf     None    False     None     None
# eta_air_line_1               0     -inf      inf     None    False     None     None
# eta_air_line_10              0     -inf      inf     None    False     None     None
# eta_air_line_13              0     -inf      inf     None    False     None     None
# eta_air_line_25              0     -inf      inf     None    False     None     None
# eta_air_line_26              0     -inf      inf     None    False     None     None
# etalon_1_amp_1_1      0.001634     -inf      inf     None     True     None     None
# etalon_1_amp_2_1      0.001634     -inf      inf     None    False etalon_1_amp_1_1     None
# etalon_1_amp_3_1      0.001634     -inf      inf     None    False etalon_1_amp_1_1     None
# etalon_1_amp_4_1      0.001634     -inf      inf     None    False etalon_1_amp_1_1     None
# etalon_1_period_1_1      1.271     -inf      inf     None    False     None     None
# etalon_1_period_2_1      1.271     -inf      inf     None    False     None     None
# etalon_1_period_3_1      1.271     -inf      inf     None    False     None     None
# etalon_1_period_4_1      1.271     -inf      inf     None    False     None     None
# etalon_1_phase_1_1     -0.7644     -inf      inf     None     True     None     None
# etalon_1_phase_2_1     -0.5136     -inf      inf     None     True     None     None
# etalon_1_phase_3_1      -1.414     -inf      inf     None     True     None     None
# etalon_1_phase_4_1           0     -inf      inf     None     True     None     None
# gamma0_air_line_1         0.04     -inf      inf     None    False     None     None
# gamma0_air_line_10     0.04463     -inf      inf     None     True     None     None
# gamma0_air_line_13      0.0432     -inf      inf     None     True     None     None
# gamma0_air_line_25        0.04     -inf      inf     None    False     None     None
# gamma0_air_line_26        0.04     -inf      inf     None    False     None     None
# molefraction_O2_1_1    0.01949     -inf      inf     None    False     None     None
# molefraction_O2_2_1    0.01949     -inf      inf     None    False     None     None
# molefraction_O2_3_1    0.01949     -inf      inf     None    False     None     None
# molefraction_O2_4_1    0.01949     -inf      inf     None    False     None     None
# nuVC_air_line_1              0     -inf      inf     None    False     None     None
# nuVC_air_line_10             0     -inf      inf     None    False     None     None
# nuVC_air_line_13             0     -inf      inf     None    False     None     None
# nuVC_air_line_25             0     -inf      inf     None    False     None     None
# nuVC_air_line_26             0     -inf      inf     None    False     None     None
# nu_1_line_1           1.315e+04 1.315e+04 1.315e+04     None    False     None     None
# nu_1_line_10          1.316e+04 1.316e+04 1.316e+04     None     True     None     None
# nu_1_line_13          1.316e+04 1.316e+04 1.316e+04     None     True     None     None
# nu_1_line_25          1.316e+04 1.316e+04 1.316e+04     None    False     None     None
# nu_1_line_26          1.316e+04 1.316e+04 1.316e+04     None    False     None     None
# nu_2_line_1           1.315e+04 1.315e+04 1.315e+04     None    False     None     None
# nu_2_line_10          1.316e+04 1.316e+04 1.316e+04     None     True     None     None
# nu_2_line_13          1.316e+04 1.316e+04 1.316e+04     None     True     None     None
# nu_2_line_25          1.316e+04 1.316e+04 1.316e+04     None    False     None     None
# nu_2_line_26          1.316e+04 1.316e+04 1.316e+04     None    False     None     None
# nu_3_line_1           1.315e+04 1.315e+04 1.315e+04     None    False     None     None
# nu_3_line_10          1.316e+04 1.316e+04 1.316e+04     None     True     None     None
# nu_3_line_13          1.316e+04 1.316e+04 1.316e+04     None     True     None     None
# nu_3_line_25          1.316e+04 1.316e+04 1.316e+04     None    False     None     None
# nu_3_line_26          1.316e+04 1.316e+04 1.316e+04     None    False     None     None
# nu_4_line_1           1.315e+04 1.315e+04 1.315e+04     None    False     None     None
# nu_4_line_10          1.316e+04 1.316e+04 1.316e+04     None     True     None     None
# nu_4_line_13          1.316e+04 1.316e+04 1.316e+04     None     True     None     None
# nu_4_line_25          1.316e+04 1.316e+04 1.316e+04     None    False     None     None
# nu_4_line_26          1.316e+04 1.316e+04 1.316e+04     None    False     None     None
# sw_1_line_1               4.37    2.185     8.74     None    False     None     None
# sw_1_line_10              4.73      2.4      9.6     None     True     None     None
# sw_1_line_13             3.086     1.56     6.24     None     True     None     None
# sw_1_line_25              2.08     1.04     4.16     None    False     None     None
# sw_1_line_26               3.4      1.7      6.8     None    False     None     None
# sw_2_line_1               4.37    2.185     8.74     None    False     None     None
# sw_2_line_10             4.748      2.4      9.6     None     True     None     None
# sw_2_line_13             3.091     1.56     6.24     None     True     None     None
# sw_2_line_25              2.08     1.04     4.16     None    False     None     None
# sw_2_line_26               3.4      1.7      6.8     None    False     None     None
# sw_3_line_1               4.37    2.185     8.74     None    False     None     None
# sw_3_line_10             4.742      2.4      9.6     None     True     None     None
# sw_3_line_13             3.094     1.56     6.24     None     True     None     None
# sw_3_line_25              2.08     1.04     4.16     None    False     None     None
# sw_3_line_26               3.4      1.7      6.8     None    False     None     None
# sw_4_line_1               4.37    2.185     8.74     None    False     None     None
# sw_4_line_10               4.8      2.4      9.6     None     True     None     None
# sw_4_line_13              3.12     1.56     6.24     None     True     None     None
# sw_4_line_25              2.08     1.04     4.16     None    False     None     None
# sw_4_line_26               3.4      1.7      6.8     None    False     None     None
# x_shift_1_1                  0     -inf      inf     None    False     None     None
# x_shift_2_1                  0     -inf      inf     None    False     None     None
# x_shift_3_1                  0     -inf      inf     None    False     None     None
# x_shift_4_1                  0     -inf      inf     None    False     None     None
# y_air_296_line_1             0     -inf      inf     None    False     None     None
# y_air_296_line_10            0     -inf      inf     None    False     None     None
# y_air_296_line_13            0     -inf      inf     None    False     None     None
# y_air_296_line_25            0     -inf      inf     None    False     None     None
# y_air_296_line_26            0     -inf      inf     None    False     None     None
# None
# /Users/wpk/Documents/python/projects/MATS/MATS/Spectrum.py:336: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.around((self.alpha.max() - self.alpha.min()) / self.residuals.std(),0)
# /Users/wpk/Documents/python/projects/MATS/MATS/Spectrum.py:336: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.around((self.alpha.max() - self.alpha.min()) / self.residuals.std(),0)
